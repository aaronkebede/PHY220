# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager
import pandas as pd
plt.rcParams.update({'font.size': 16})
plt.rcParams.update({
    "text.usetex": True,
    "font.weight": "bold",
    "font.family": "serif",
    "font.sans-serif": ["Helvetica"]})

# %%
#Load data

amplitude = pd.read_csv("v1/Readings/amp.csv") 
frequency = pd.read_csv("v1/Readings/freq.csv")
phase     = pd.read_csv("v1/Readings/phase.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_145007/1753340677.py in <module>
#       1 #Load data
#       2
# ----> 3 amplitude = pd.read_csv("v1/Readings/amp.csv")
#       4 frequency = pd.read_csv("v1/Readings/freq.csv")
#       5 phase     = pd.read_csv("v1/Readings/phase.csv")
#
# ...

# %%
# load amplitude, frequency, phase into arrays

amplitude = np.array(amplitude)
frequency = np.array(frequency)
phase     = np.array(phase)

# %%
frequency_axis         = frequency[:,1]
time_frequency_axis    = frequency[:,0]
amplitude_axis         = amplitude[:,1]
time_amplitude_axis    = amplitude[:,0]
phase_axis             = phase[:,1]
time_phase_axis        = phase[:,0]

# %%
plt.plot(time_frequency_axis,frequency_axis, lw=2)
plt.grid()
plt.xlabel("Time (sec)")
plt.ylabel("Frequency (KHz)")
plt.title("Change in Frequency with Time")
plt.show()

# %%
plt.plot(time_amplitude_axis,amplitude_axis,lw=2)
plt.grid()
plt.xlabel("Time (sec)")
plt.ylabel("Amplitude (V)")
plt.title("Change in Amplitude with Time")
plt.show()

# %%
plt.plot(time_phase_axis,phase_axis, '--',lw=2)
plt.grid()
plt.xlabel("Time (sec)")
plt.ylabel("Phase (degrees)")
plt.title("Change in Phase with Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145007/3621663976.py in <module>
# ----> 1 plt.plot(time_phase_axis,phase_axis, '--',lw=2)
#       2 plt.grid()
#       3 plt.xlabel("Time (sec)")
#       4 plt.ylabel("Phase (degrees)")
#       5 plt.title("Change in Phase with Time")
#
# NameError: name 'plt' is not defined

# %%
# We have to reshape the frequency array to make it the same size as the amplitude one

resized_frequency_axis = frequency_axis[210:]

# Let's define two functions to see how the frequecy & amp change with time in each array

r_freq = frequency_axis / time_frequency_axis
r_amp  = amplitude_axis / time_amplitude_axis

# %%
resized_r_freq = r_freq[210:]

# %%
# A plot of Ampllitude against time
plt.plot(resized_frequency_axis,amplitude_axis,lw=2)
plt.grid()
plt.xlabel("Amplitude")
plt.ylabel("Frequency")
plt.title("Change in amplitude with frequency")
plt.show()

# %%
#Plot Rate of amplitude change against rate of frequency change
plt.plot(resized_r_freq,r_amp, lw=4, ls='dotted', c="salmon")
plt.grid()
plt.xlabel("Rate of Frequency Change (KHz/sec")
plt.ylabel("Rate of Amplitude Change (V/sec)")
plt.title("Rate of Amplitude change aganinst the Rate of Frequency change")
plt.show()
